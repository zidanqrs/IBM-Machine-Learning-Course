# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Hyperparameter Optimization for Keras with Scikit-Learn**

# %% [markdown]
# Estimated time needed: **35** minutes

# %% [markdown]
# We already know how to use `RandomizedSearchCV` and `GridSearchCV` for hyperparameter tuning in machine learning models - linear regression,  decision trees, and so on. It turns out that we can utilize the same functionality easily for neural networks! Keras offers a scikit-learn wrapper that lets us perform randomized/grid search on its models using the same syntax (example `fit()`, `.best_score_`). In this lab, we will take a look at how to do so for a Sequential model.
#
# As a reminder, both search types may take a long time to run for this lab.

# %% [markdown]
# ## **Table of Contents**
#
# <ol>
#     <li><a href="https://#Objectives">Objectives</a></li>
#     <li>
#         <a href="https://#Setup">Setup</a>
#         <ol>
#             <li><a href="https://#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="https://#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="https://#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Create-the-Model">Create the Model</a>
#         <ol>
#             <li><a href="https://#Load-the-Data">Load the Data</a></li>
#             <li><a href="https://#Data-Wrangling">Data Wrangling</a></li>
#             <li><a href="https://#Build-the-Base-Model">Build the Base Model</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Randomized-Search">Randomized Search</a>
#         <ol>
#             <li><a href="https://#Parameters">Parameters</a></li>
#             <li><a href="https://#Define-and-Fit-RandomizedSearchCV">Define and Fit RandomizedSearchCV</a></li>
#             <li><a href="https://#Performance-Evaluation">Performance Evaluation</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Exercised">Exercises</a>
#         <ol>
#             <li><a href="https://#Exercise-1:-Build-the-Base-Model">Exercise 1: Build the Base Model</a></li>
#             <li><a href="https://#Exercise-2:-Define-Search-Parameters">Exercise 2: Define Search Parameters</a></li>
#             <li><a href="https://#Exercise-3:-Fit-RandomizedSearchCV">Exercise 3: Fit RandomizedSearchCV</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Use Keras' scikit-learn wrapper to utilize sklearn functions on Keras models
# *   Apply randomized search on Keras models to find the best hyperparameters

# %% [markdown]
# ***

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.
# *   [`tensorflow`](https://www.tensorflow.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and neural network related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook command in a different Jupyter environment (like Watson Studio or Anaconda), you will need to install these libraries by removing the `#` sign before `!mamba` in the following code cell.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# The following required libraries are **not** pre-installed in the Skills Network Labs environment. **You will need to run the following cell** to install them:

# %%
#!mamba install -qy tqdm

# %%
# Upgrade to newest version of skillsnetwork for more functionalities
# Restart kernel after doing so
# %pip install --upgrade skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in c:\users\user\anaconda3\lib\site-packages (0.20.6)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from skillsnetwork) (8.15.0)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\user\anaconda3\lib\site-packages (from skillsnetwork) (7.8.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from skillsnetwork) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\user\anaconda3\lib\site-packages (from skillsnetwork) (4.65.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (1.1.7)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2023.7.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\user\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (7.4.9)
# Requirement already satisfied: nbformat in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.25.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\user\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.5)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from asttokens->stack-data->ipython->skillsnetwork) (1.16.0)
# Requirement already satisfied: entrypoints in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.2.2)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.12.2)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.13)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.6.7)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\user\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.4)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing Required Libraries

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # tensorflow INFO and WARNING messages are not printed
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from tqdm import tqdm
import numpy as np
# %matplotlib inline

import tensorflow as tf
import keras
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier

import skillsnetwork

# %% [markdown]
# ### Defining Helper Functions

# %%
# Vectorize integer sequence
def vectorize_sequence(sequence, dimensions):
    results = np.zeros((len(sequence), dimensions))
    for index,value in enumerate(sequence):
        if max(value) < dimensions:
            results[index, value] = 1
    return results

# Convert label into one-hot format
def one_hot_label(labels, dimensions):
    results = np.zeros((len(labels), dimensions))
    for index,value in enumerate(labels):
        if value < dimensions:
            results[index, value] = 1
    return results

# %% [markdown]
# ## Create the Model

# %% [markdown]
# ### Load the Data

# %% [markdown]
# For this exercise, we will be using the [Reuters newswire classification dataset](https://keras.io/api/datasets/reuters/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) from Keras. The training features for this dataset are lists of word indices (integers), corresponding to their frequency in the dataset. The response labels take on one of 46 classes, representing the newswire's topic.

# %%
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module2/L1/reuters.npz", overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module2/L1/reuters.npz", overwrite=True)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\skillsnetwork\core.py:249, in prepare(url, path, verbose, overwrite)
#     246 tmp_download_file = Path(f"/tmp/{dname}-{filename}")
#     247 # Download the dataset to tmp_download_file file
#     248 # File will be overwritten if it already exists
# --> 249 await download(url, tmp_download_file, verbose=False)
#     251 # Delete extract_dir directory if it already exists
#     252 if not _is_jupyterlite():
#
# File c:\Users\USER\anaconda3\Lib\site-packages\skillsnetwork\core.py:186, in download(url, path, verbose, chunk_size)
#     184     if path.is_dir():
#     185         path /= filename
# --> 186 with open(path, "wb") as f:  # Will raise FileNotFoundError if invalid path
#     187     async for chunk in _get_chunks(url, chunk_size):
#     188         f.write(chunk)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\tmp\\skills-network--1801421118617550701-reuters.npz'

# %%
X = np.load("x.npy", allow_pickle=True)
y = np.load ("y.npy", allow_pickle=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# To get the word for a specific index, we can also extract a dictionary of words to index using the following Keras function.

# %%
word_to_ind = tf.keras.datasets.reuters.get_word_index(path="reuters_word_index.json")

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Since each observation is a list of words that appear in the newswire, the length varies. Hence, we will vectorize the dataset using `vectorize_sequence()` to ensure that all inputs to our model have the same dimension. Labels are also one-hot encoded with `one_hot_label()` because classes (news topic) are not ordinal.

# %%
dim_x = max([max(sequence) for sequence in X_train])+1
dim_y = max(y_train)+1

X_train_vec = vectorize_sequence(X_train, dim_x)
X_test_vec = vectorize_sequence(X_test, dim_x)
y_train_hot = one_hot_label(y_train, dim_y)
y_test_hot = one_hot_label(y_test, dim_y)

# %% [markdown]
# ### Build the Base Model

# %% [markdown]
# In order to apply `RandomizedSearchCV` on Keras models, we will be using `KerasClassifier` from `keras.wrappers.scikit_learn` library, which will let us apply scikit-learn functions on the model.

# %% [markdown]
# We define `create_model()` below to detail which layers we want to include in the model. Recall that the final Dense layer has 46 units to correspond to the number of classes. This also prompts us to use categorical cross entropy as a loss function. Here, `neuron` is included as a parameter with default value because we want to tune it later.

# %%
# Create Keras Sequential Model as base model
def create_model(neurons = 10):
    model = Sequential()
    model.add(Dense(neurons, activation='linear'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# For the base model, we won't change any parameters so that we can compare them with results after hyperparameter tuning. We also specify some of the default values for hyperparameters that don't appear in `create_model()` (example batch_size, epochs) such that they are defined when applying randomized search.

# %%
np.random.seed(0)
base_model = KerasClassifier(build_fn=create_model, verbose=0, batch_size=10, epochs=1)

# %% [markdown]
# Fitting the model on the train set, we obtain the test score for our base model.

# %%
# Get pre-tuned results
base_model.fit(X_train_vec, y_train_hot)
base_score = base_model.score(X_test_vec, y_test_hot)
print("The baseline accuracy is: %.3f" % base_score)

# %% [markdown]
# ## Randomized Search

# %% [markdown]
# ### Parameters

# %% [markdown]
# As you might already know from performing randomized search on machine learning models, we have to create a dictionary for the hyperparameter values. Let's start by defining the values we want to experiment with! Note that if you would like to test other parameters, they must be defined in the base model as well.

# %%
batch_size = [10, 20, 60, 80]
epochs = [1, 3, 5]
neurons = [1, 10, 20, 30]

params = dict(batch_size=batch_size, epochs=epochs, neurons=neurons)
params

# %% [markdown]
# ### Define and Fit RandomizedSearchCV

# %%
search = RandomizedSearchCV(estimator=base_model, param_distributions=params, cv=3)

# %% [markdown]
# Now, fit randomized search on `X_train_vec` and `y_train_hot` as you would for any other model. **Note that this may take a while to run (10+ minutes)**, especially if there are a lot of parameter combinations, or if the epoch size is big. If you have the resources, you could also switch out `RandomizedSearchCV` for `GridSearchCV` to search over every combination of hyperparameters (takes even more time to run).

# %%
search_result = search.fit(X_train_vec, y_train_hot)

# %% [markdown]
# ### Performance Evaluation

# %% [markdown]
# Let's take a look at the results from this search! In particular, we will examine the mean and standard deviation of the cross-validation score under different hyperparameter combinations.

# %%
means = search_result.cv_results_['mean_test_score']
stds = search_result.cv_results_['std_test_score']
params = search_result.cv_results_['params']

# %% [markdown]
# `RandomizedSearchCV` also has attributes for us to access the best score and parameters directly.

# %%
print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))

# %% [markdown]
# We can also print out all the other scores:

# %%
for mean, stdev, param in zip(means, stds, params):
    print("Mean cross-validated score: {} ({}) using: {}".format(round(mean,3), round(stdev,3), param))

# %% [markdown]
# From this, we can see how different the other models' scores are compared to the optimal model's performance. Some are pretty close to the best score, whereas there are combinations that yield much lower scores.Thank goodness we didn't pick those! With randomized search on neural networks, we are able to determine the best values in an automated way.

# %% [markdown]
# Using the best estimator, let's get the test score:

# %%
print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))

# %% [markdown]
# Our test score has increased compared to the base model!

# %% [markdown]
# ## Exercises

# %% [markdown]
# Now, let's try Randomized search on other hyperparameters!

# %% [markdown]
# ### Exercise 1: Build the Base Model

# %% [markdown]
# This time, we want to look at different optimizers, learning rates, and dropout rates. Since the learning rate is a value fed into `optimizer`, the parameter has to be named a certain way in `create_model()` and `params`: `optimizer__learning_rate`.

# %%
# Create Keras Sequential Model as base model
def create_model(optimizer = 'RMSprop', optimizer__learning_rate = 0.1, dropout_rate = 0.2):
    model = Sequential()
    model.add(Dense(64, activation='linear'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# TODO: Create `base_model` using `KerasClassifier`. Fit it to the training set and obtain the test score

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# np.random.seed(0)
# base_model = KerasClassifier(build_fn=create_model, verbose=0, batch_size=100, epochs=1)
# base_model.fit(X_train_vec, y_train_hot)
# base_score = base_model.score(X_test_vec, y_test_hot)
# print("The baseline accuracy is: {}".format(base_score))
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2: Define Search Parameters

# %% [markdown]
# Now, we will specify which values we want to experiment with and put them into a dictionary.

# %%
# TODO: specify 3-4 values for each of the following parameters

# TODO: convert it into a dictionary variable named `params`

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# optimizer = ['SGD','RMSprop','Adam']
# learning_rate = [0.01, 0.1, 1]
# dropout_rate = [0.1, 0.3, 0.6, 0.9]
# params = dict(optimizer=optimizer, optimizer__learning_rate=learning_rate, dropout_rate = dropout_rate)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Fit RandomizedSearchCV **(Note that this may take a while to run (5+ minutes))**

# %%
# TODO: Create `RandomizedSearchCV` object `search` and fit it to the train set

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# search = RandomizedSearchCV(estimator=base_model, param_distributions=params, cv=3)
# search_result = search.fit(X_train_vec, y_train_hot)
#
# ```
#
# </details>

# %%
# TODO: Obtain the best cross-validation score and test scores

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))
# print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))
#
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Cindy Huang](https://www.linkedin.com/in/cindy-shih-ting-huang/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) is a data science associate of the Skills Network team. She has a passion for machine learning to improve user experience, especially in the area of computational linguistics.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Contributor with Link](contributor_linl), Contributor No Link

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description |
# | ----------------- | ------- | ---------- | ------------------ |
# | 2022-07-20        | 1.0     | Cindy H.   | Create lab draft   |
# | 2022-09-01        | 1.0     | Steve Hord | QA pass edits      |
# | 2022-11-11        | 1.0     | Shengkai C.| Review and edit    |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
