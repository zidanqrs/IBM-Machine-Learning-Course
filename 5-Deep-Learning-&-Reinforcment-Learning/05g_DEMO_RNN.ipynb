# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Machine Learning Foundation
#
# ## Course 5, Part g: RNN DEMO

# %% [markdown]
# ## Using RNNs to classify sentiment on IMDB data
# For this exercise, we will train a "vanilla" RNN to predict the sentiment on IMDB reviews.  Our data consists of 25000 training sequences and 25000 test sequences.  The outcome is binary (positive/negative) and both outcomes are equally represented in both the training and the test set.
#
# Keras provides a convenient interface to load the data and immediately encode the words into integers (based on the most common words).  This will save us a lot of the drudgery that is usually involved when working with raw text.
#
# We will walk through the preparation of the data and the building of an RNN model.  Then it will be your turn to build your own models (and prepare the data how you see fit).

# %%
# %%capture
# !pip install --upgrade tensorflow

# %%
from tensorflow import keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import SimpleRNN
from keras.datasets import imdb
from keras import initializers
# Out:
# WARNING:tensorflow:From c:\Users\USER\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 30  # maximum length of a sequence - truncate after this
batch_size = 32

# %%
## Load in the data.  The function automatically tokenizes the text into distinct integers
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# 25000 train sequences
# 25000 test sequences

# %%
# This pads (or truncates) the sequences so that they are of the maximum length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (25000, 30)
# x_test shape: (25000, 30)

# %%
x_train[123,:]  #Here's what an example sequence looks like
# Out:
# array([  219,   141,    35,   221,   956,    54,    13,    16,    11,
#         2714,    61,   322,   423,    12,    38,    76,    59,  1803,
#           72,     8, 10508,    23,     5,   967,    12,    38,    85,
#           62,   358,    99])

# %% [markdown]
# ## Keras layers for (Vanilla) RNNs
#
# In this exercise, we will not use pre-trained word vectors.  Rather we will learn an embedding as part of the Neural Network.  This is represented by the Embedding Layer below.
#
# ### Embedding Layer
# `keras.layers.embeddings.Embedding(input_dim, output_dim, embeddings_initializer='uniform', embeddings_regularizer=None, activity_regularizer=None, embeddings_constraint=None, mask_zero=False, input_length=None)`
#
# - This layer maps each integer into a distinct (dense) word vector of length `output_dim`.
# - Can think of this as learning a word vector embedding "on the fly" rather than using an existing mapping (like GloVe)
# - The `input_dim` should be the size of the vocabulary.
# - The `input_length` specifies the length of the sequences that the network expects.
#
# ### SimpleRNN Layer
# `keras.layers.recurrent.SimpleRNN(units, activation='tanh', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, dropout=0.0, recurrent_dropout=0.0)`
#
# - This is the basic RNN, where the output is also fed back as the "hidden state" to the next iteration.
# - The parameter `units` gives the dimensionality of the output (and therefore the hidden state).  Note that typically there will be another layer after the RNN mapping the (RNN) output to the network output.  So we should think of this value as the desired dimensionality of the hidden state and not necessarily the desired output of the network.
# - Recall that there are two sets of weights, one for the "recurrent" phase and the other for the "kernel" phase.  These can be configured separately in terms of their initialization, regularization, etc.

# %%
## Let's build a RNN

rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence and embeds it in a 50-dimensional vector
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From c:\Users\USER\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
## Note that most of the parameters come from the embedding layer
model_rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 50)          1000000
#
#  simple_rnn (SimpleRNN)      (None, 5)                 280
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 1000286 (3.82 MB)
# Trainable params: 1000286 (3.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\USER\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\USER\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 782/782 [==============================] - 7s 7ms/step - loss: 0.6918 - accuracy: 0.5228 - val_loss: 0.6873 - val_accuracy: 0.5190
# Epoch 2/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.6658 - accuracy: 0.6220 - val_loss: 0.6385 - val_accuracy: 0.6714
# Epoch 3/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6047 - accuracy: 0.6995 - val_loss: 0.5847 - val_accuracy: 0.7031
# Epoch 4/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.5465 - accuracy: 0.7360 - val_loss: 0.5490 - val_accuracy: 0.7186
# Epoch 5/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.5057 - accuracy: 0.7598 - val_loss: 0.5272 - val_accuracy: 0.7330
# Epoch 6/10
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4760 - accuracy: 0.7778 - val_loss: 0.5208 - val_accuracy: 0.7392
# Epoch 7/10
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4528 - accuracy: 0.7912 - val_loss: 0.4966 - val_accuracy: 0.7523
# Epoch 8/10
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4341 - accuracy: 0.8015 - val_loss: 0.4870 - val_accuracy: 0.7607
# Epoch 9/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.4182 - accuracy: 0.8115 - val_loss: 0.4772 - val_accuracy: 0.7658
# Epoch 10/10
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4050 - accuracy: 0.8199 - val_loss: 0.4722 - val_accuracy: 0.7671

# %%
score, acc = model_rnn.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 782/782 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.7671
# Test score: 0.4722127318382263
# Test accuracy: 0.7671200037002563

# %% [markdown]
# ## Exercise
#
# In this exercise, we will illustrate:
# - Preparing the data to use sequences of length 80 rather than length 30.  Does it improve the performance?
# - Trying different values of the "max_features".  Does this  improve the performance?
# - Trying smaller and larger sizes of the RNN hidden dimension.  How does it affect the model performance?  How does it affect the run time?

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 13s 15ms/step - loss: 0.6537 - accuracy: 0.6068 - val_loss: 0.5774 - val_accuracy: 0.6975
# Epoch 2/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.5044 - accuracy: 0.7546 - val_loss: 0.5238 - val_accuracy: 0.7304
# Epoch 3/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.4187 - accuracy: 0.8115 - val_loss: 0.4517 - val_accuracy: 0.7866
# Epoch 4/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.3694 - accuracy: 0.8397 - val_loss: 0.4115 - val_accuracy: 0.8104
# Epoch 5/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3352 - accuracy: 0.8569 - val_loss: 0.3976 - val_accuracy: 0.8173
# Epoch 6/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.3120 - accuracy: 0.8682 - val_loss: 0.3845 - val_accuracy: 0.8265
# Epoch 7/10
# 782/782 [==============================] - 13s 17ms/step - loss: 0.2935 - accuracy: 0.8790 - val_loss: 0.3747 - val_accuracy: 0.8322
# Epoch 8/10
# 782/782 [==============================] - 12s 16ms/step - loss: 0.2784 - accuracy: 0.8859 - val_loss: 0.3743 - val_accuracy: 0.8327
# Epoch 9/10
# 782/782 [==============================] - 10s 12ms/step - loss: 0.2673 - accuracy: 0.8925 - val_loss: 0.3741 - val_accuracy: 0.8349
# Epoch 10/10
# 782/782 [==============================] - 10s 12ms/step - loss: 0.2569 - accuracy: 0.8984 - val_loss: 0.3715 - val_accuracy: 0.8370

# %%
max_features = 5000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 20
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 11s 12ms/step - loss: 0.6928 - accuracy: 0.5067 - val_loss: 0.6915 - val_accuracy: 0.5027
# Epoch 2/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.6813 - accuracy: 0.5408 - val_loss: 0.6661 - val_accuracy: 0.5874
# Epoch 3/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.6354 - accuracy: 0.6665 - val_loss: 0.5887 - val_accuracy: 0.7069
# Epoch 4/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.5328 - accuracy: 0.7382 - val_loss: 0.5222 - val_accuracy: 0.7397
# Epoch 5/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.4780 - accuracy: 0.7710 - val_loss: 0.4892 - val_accuracy: 0.7619
# Epoch 6/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.4429 - accuracy: 0.7951 - val_loss: 0.4758 - val_accuracy: 0.7692
# Epoch 7/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.4155 - accuracy: 0.8132 - val_loss: 0.4476 - val_accuracy: 0.7881
# Epoch 8/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.3948 - accuracy: 0.8251 - val_loss: 0.4325 - val_accuracy: 0.7960
# Epoch 9/10
# 782/782 [==============================] - 10s 12ms/step - loss: 0.3782 - accuracy: 0.8339 - val_loss: 0.4245 - val_accuracy: 0.8054
# Epoch 10/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.3648 - accuracy: 0.8413 - val_loss: 0.4124 - val_accuracy: 0.8112

# %%
# Out of curiosity, run for 10 more epochs
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.3509 - accuracy: 0.8482 - val_loss: 0.3991 - val_accuracy: 0.8196
# Epoch 2/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.3373 - accuracy: 0.8573 - val_loss: 0.4010 - val_accuracy: 0.8223
# Epoch 3/10
# 782/782 [==============================] - 10s 12ms/step - loss: 0.3271 - accuracy: 0.8602 - val_loss: 0.4089 - val_accuracy: 0.8089
# Epoch 4/10
# 782/782 [==============================] - 9s 12ms/step - loss: 0.3182 - accuracy: 0.8652 - val_loss: 0.3752 - val_accuracy: 0.8325
# Epoch 5/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.3105 - accuracy: 0.8700 - val_loss: 0.3716 - val_accuracy: 0.8338
# Epoch 6/10
# 782/782 [==============================] - 9s 12ms/step - loss: 0.3046 - accuracy: 0.8716 - val_loss: 0.3675 - val_accuracy: 0.8372
# Epoch 7/10
# 782/782 [==============================] - 9s 12ms/step - loss: 0.2994 - accuracy: 0.8752 - val_loss: 0.3647 - val_accuracy: 0.8384
# Epoch 8/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.2950 - accuracy: 0.8769 - val_loss: 0.3654 - val_accuracy: 0.8382
# Epoch 9/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.2909 - accuracy: 0.8786 - val_loss: 0.3650 - val_accuracy: 0.8396
# Epoch 10/10
# 782/782 [==============================] - 9s 12ms/step - loss: 0.2872 - accuracy: 0.8814 - val_loss: 0.3632 - val_accuracy: 0.8414

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation
